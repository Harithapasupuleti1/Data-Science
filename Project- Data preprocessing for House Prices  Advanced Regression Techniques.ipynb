# %% [markdown]
# # Import required libraries for data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Export of multiple data set files

# %%
import glob # which is required to import multiples files at a time

# %%
files=glob.glob("C:\\Users\\Administrator\\Documents\\Python Scripts\\Python\Datasets\\*.csv")

# %%
files
# Out:
# ['C:\\Users\\Administrator\\Documents\\Python Scripts\\Python\\Datasets\\sample_submission.csv',
#  'C:\\Users\\Administrator\\Documents\\Python Scripts\\Python\\Datasets\\test.csv',
#  'C:\\Users\\Administrator\\Documents\\Python Scripts\\Python\\Datasets\\train.csv']

# %%
train_data=pd.read_csv(files[2])
test_data=pd.read_csv(files[1])
sample_submission=pd.read_csv(files[0])

# %%
len(train_data),len(test_data),len(sample_submission) # Total no of rows in each data set
# Out:
# (1460, 1459, 1459)

# %%
len(train_data.columns),len(test_data.columns),len(sample_submission.columns) # Total no of columns in each data set
# Out:
# (81, 80, 2)

# %% [markdown]
# # Data preprocessing steps

# %% [markdown]
# 1. Identification of numerical and categorical varaibles
# 2. Null value treatment
# 3. Outliers Treatment
# 4. Label Encoders
# 5. Memory management

# %% [markdown]
# # Identification of numerical and categorical varaibles

# %%
train_data.drop('Id',axis=1,inplace=True)

# %%
numerical=train_data.mean().index

# %%
len(numerical)
# Out:
# 37

# %%
cat=[]

for i in train_data.columns:
    if i not in numerical:
        cat.append(i)
print(cat)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
len(cat)
# Out:
# 43

# %%
# Identification of numerical class,count and categorical class and count varaibles

numerical_class=[]
numerical_cont=[]

for i in train_data[numerical].columns:
    if train_data[i].nunique()<8:
        numerical_class.append(i)
    else:
        numerical_cont.append(i)

cat_class=[]
cat_cont=[]

for i in train_data[cat].columns:
    if train_data[i].nunique()<8:
        cat_class.append(i)
    else:
        cat_cont.append(i)
    
print("numerical:", len(numerical))
print("numerical_cont:", len(numerical_cont))
print("numerical_class:", len(numerical_class))
print("cat:", len(cat))
print("cat_class:", len(cat_class))
print("cat_cont:", len(cat_cont))
# Out:
# numerical: 37
# numerical_cont: 29
# numerical_class: 8
# cat: 43
# cat_class: 35
# cat_cont: 8

# %% [markdown]
# # Null value Treatment

# %%
train_data.isna().sum() # Which display total count of null values for each column
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %%
Null_value_Table=(train_data.isna().sum()/train_data.shape[0])*100 # Displaying null % for each column

# %%
Null_value_Table
# Out:
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.547945
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
#                    ...
# BedroomAbvGr      0.000000
# KitchenAbvGr      0.000000
# KitchenQual       0.000000
# ...

# %%
for i in train_data[numerical_class].columns:
    train_data[i].fillna(train_data[i].value_counts().index[0],inplace=True)
for i in train_data[numerical_cont].columns:
    train_data[i].fillna(train_data[i].median(),inplace=True)
for i in train_data[cat_class].columns:
    train_data[i].fillna(train_data[i].value_counts().index[0],inplace=True)

# %%
train_data.isna().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
#                 ..
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageYrBlt      0
# GarageFinish     0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# ...

# %% [markdown]
# # Outliers Treatment

# %% [markdown]
# Values which are less than lower whiskler length(Q1-1.5(IQR)) and more tham upper whiskler length(Q3+1.5(IQR)) are treated as outliers

# %%
import numpy as np
all_outliers=[]
def outliers(train_data):
    for i in train_data[numerical_cont].columns:
        print(i)
        q1=np.quantile(train_data[i].values,0.25)
        q3=np.quantile(train_data[i].values,0.75)
        IQR=q3-q1
        lwl=q1-1.5*(IQR)
        uwl=q3+1.5*(IQR)
        outliers_data=[]
        X=[]
        for j in train_data[i].values:
            if (j<lwl) or (j>uwl):
                outliers_data.append(j)
                X.append(train_data[i].median())
            else:
                X.append(j)
        print("             ")
        all_outliers.append([i,outliers_data])
        train_data[i]=X

# %%
outliers(train_data)
# Out:
# MSSubClass
#
# LotFrontage
#
# LotArea
#
# OverallQual
#
# OverallCond
#
# YearBuilt
#
# YearRemodAdd
#
# MasVnrArea
#
# BsmtFinSF1
#
# BsmtFinSF2
#
# BsmtUnfSF
#
# TotalBsmtSF
#
# 1stFlrSF
#
# 2ndFlrSF
#
# LowQualFinSF
#
# GrLivArea
#
# BedroomAbvGr
#
# TotRmsAbvGrd
#
# GarageYrBlt
#
# GarageArea
#
# WoodDeckSF
#
# OpenPorchSF
#
# EnclosedPorch
#
# 3SsnPorch
#
# ScreenPorch
#
# PoolArea
#
# MiscVal
#
# MoSold
#
# SalePrice

# %%
pd.DataFrame(all_outliers)
# Out:
#                 0                                                  1
# 0      MSSubClass  [190, 190, 160, 180, 160, 190, 160, 190, 160, ...
# 1     LotFrontage  [110.0, 108.0, 112.0, 115.0, 110.0, 24.0, 21.0...
# 2         LotArea  [50271, 19900, 21000, 21453, 19378, 31770, 229...
# 3     OverallQual                                             [1, 1]
# 4     OverallCond  [8, 8, 8, 2, 3, 8, 8, 8, 8, 9, 8, 9, 9, 3, 9, ...
# 5       YearBuilt         [1880, 1880, 1880, 1882, 1880, 1875, 1872]
# 6    YearRemodAdd                                                 []
# 7      MasVnrArea  [640.0, 650.0, 412.0, 456.0, 1031.0, 573.0, 11...
# 8      BsmtFinSF1         [1810, 1880, 1904, 2260, 2188, 2096, 5644]
# 9      BsmtFinSF2  [32, 668, 486, 93, 491, 506, 712, 362, 41, 169...
# 10      BsmtUnfSF  [1777, 1768, 1907, 1686, 2336, 1694, 2121, 186...
# 11    TotalBsmtSF  [0, 0, 2223, 0, 0, 0, 2216, 0, 2392, 0, 2121, ...
# 12       1stFlrSF  [2207, 2223, 2259, 2158, 2234, 2392, 2402, 322...
# ...

# %% [markdown]
# # Data Visualization for numerical count using plotly and cufflinks which are create interactive plots which can used in dashboard

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
import cufflinks as cf

# %%
# For Notebooks
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# For offline use
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
train_data[numerical_cont].columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BedroomAbvGr', 'TotRmsAbvGrd', 'GarageYrBlt',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'SalePrice'],
#       dtype='object')

# %%
train_data_numerical=train_data[train_data[numerical_cont].columns]

# %%
train_data_numerical
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0           60.0         65.0   8450.0          7.0          5.0     2003.0
# 1           20.0         80.0   9600.0          6.0          5.0     1976.0
# 2           60.0         68.0  11250.0          7.0          5.0     2001.0
# 3           70.0         60.0   9550.0          7.0          5.0     1915.0
# 4           60.0         84.0  14260.0          8.0          5.0     2000.0
# 5           50.0         85.0  14115.0          5.0          5.0     1993.0
# 6           20.0         75.0  10084.0          8.0          5.0     2004.0
# 7           60.0         69.0  10382.0          7.0          6.0     1973.0
# 8           50.0         51.0   6120.0          7.0          5.0     1931.0
# 9           50.0         50.0   7420.0          5.0          6.0     1939.0
# 10          20.0         70.0  11200.0          5.0          5.0     1965.0
# ...

# %% [markdown]
# # Box plot for identification of outliers

# %%
train_data_numerical.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="d7715939-697d-4d27-bb8f-7fffe5b330e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d7715939-697d-4d27-bb8f-7fffe5b330e3")) {
#                     Plotly.newPlot(
#                         'd7715939-697d-4d27-bb8f-7fffe5b330e3',
# ...

# %% [markdown]
# # Label Encoder

# %% [markdown]
# label Encoder which can decode the values into numeric for categorical varaibles which can be easy to understand

# %%
from sklearn.preprocessing import LabelEncoder

# %%
train_data[train_data[cat_class].columns]
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave  Grvl      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave  Grvl      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave  Grvl      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave  Grvl      IR1         Lvl    AllPub       FR2       Gtl
# 5          RL   Pave  Grvl      IR1         Lvl    AllPub    Inside       Gtl
# 6          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 7          RL   Pave  Grvl      IR1         Lvl    AllPub    Corner       Gtl
# 8          RM   Pave  Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 9          RL   Pave  Grvl      Reg         Lvl    AllPub    Corner       Gtl
# 10         RL   Pave  Grvl      Reg         Lvl    AllPub    Inside       Gtl
# ...

# %%
for i in train_data[cat_class].columns:
    le=LabelEncoder()
    le.fit(train_data[i])
    transformed_values=le.transform(train_data[i])
    train_data[i]=transformed_values

# %%
train_data[train_data[cat_class].columns] # converted all values in cateforical class into numerical values
# Out:
#       MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0            3       1      0         3            3          0          4
# 1            3       1      0         3            3          0          2
# 2            3       1      0         0            3          0          4
# 3            3       1      0         0            3          0          0
# 4            3       1      0         0            3          0          2
# 5            3       1      0         0            3          0          4
# 6            3       1      0         3            3          0          4
# 7            3       1      0         0            3          0          0
# 8            4       1      0         3            3          0          4
# 9            3       1      0         3            3          0          0
# 10           3       1      0         3            3          0          4
# ...

# %% [markdown]
# Memory management

# %%
""" iterate through all the columns of a dataframe and modify the data type
    to reduce memory usage.        
"""
start_mem = train_data.memory_usage().sum() / 1024**2
print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

for col in train_data.columns:
    col_type = train_data[col].dtype

    if col_type != object:
        c_min = train_data[col].min()
        c_max = train_data[col].max()
        if str(col_type)[:3] == 'int':
            if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                train_data[col] = train_data[col].astype(np.int8)
            elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                train_data[col] = train_data[col].astype(np.int16)
            elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                train_data[col] = train_data[col].astype(np.int32)
            elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                train_data[col] = train_data[col].astype(np.int64)  
        else:
            if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                train_data[col] = train_data[col].astype(np.float16)
            elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                train_data[col] = train_data[col].astype(np.float32)
            else:
                train_data[col] = train_data[col].astype(np.float64)
    else:
        train_data[col] = train_data[col].astype('category')

end_mem = train_data.memory_usage().sum() / 1024**2
print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
# Out:
# Memory usage of dataframe is 0.70 MB
# Memory usage after optimization is: 0.16 MB
# Decreased by 77.2%

# %% [markdown]
# # Pandas profiling report

# %% [markdown]
#  Report which helps for quick glance on how many varaibles exist and categories of data types with measures of dispersion values such as mean and median along with correlation matrix

# %%
import pandas_profiling as pp

# %%
X=train_data.ix[:,0:train_data.shape[1]-1]
# Out:
# C:\Users\Administrator\Haritha\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
X.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0        60.0         3         65.0   8448.0       1      0         3
# 1        20.0         3         80.0   9600.0       1      0         3
# 2        60.0         3         68.0  11248.0       1      0         0
# 3        70.0         3         60.0   9552.0       1      0         0
# 4        60.0         3         84.0  14256.0       1      0         0
#
#    LandContour  Utilities  LotConfig  ...  ScreenPorch PoolArea PoolQC Fence  \
# 0            3          0          4  ...          0.0      0.0      2     2
# 1            3          0          2  ...          0.0      0.0      2     2
# 2            3          0          4  ...          0.0      0.0      2     2
# 3            3          0          0  ...          0.0      0.0      2     2
# 4            3          0          2  ...          0.0      0.0      2     2
#
#    MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
pp.ProfileReport(X)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...
